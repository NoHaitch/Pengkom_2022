# %%
# NIM/Nama : 19622078 / Raden Francisco Trianto Bratadiningrat
# Tanggal : 23 November 2022
# Deskripsi : Problem 1, data harga rumah sewa di Airbnb Singapura

# import library 
import pandas as pd
# loading data
df = pd.read_csv("P05-03.csv")
df
# Out:
#             id                                               name    host_id  \
# 0        49091                  COZICOMFORT LONG TERM STAY ROOM 2     266763
# 1        50646                    Pleasant Room along Bukit Timah     227796
# 2        56334                                        COZICOMFORT     266763
# 3        71609                Ensuite Room (Room 1 & 2) near EXPO     367042
# 4        71896                    B&B  Room 1 near Airport & EXPO     367042
# ...        ...                                                ...        ...
# 7902  38105126  Loft 2 pax near Haw Par / Pasir Panjang. Free ...  278109833
# 7903  38108273                         3bedroom luxury at Orchard  238891646
# 7904  38109336    [ Farrer Park ] New City Fringe CBD Mins to MRT  281448565
# 7905  38110493          Cheap Master Room in Central of Singapore  243835202
# 7906  38112762  Amazing room with private bathroom walk to Orc...   28788520
#
# ...

# %%
# no 1 : Banyaknya rumah masing-masing tipe kamar
df["room_type"].value_counts().rename_axis("Tipe_kamar").reset_index(name="Jumlah mahasiswa")
# Out:
#         Tipe_kamar  Jumlah mahasiswa
# 0  Entire home/apt              4132
# 1     Private room              3381
# 2      Shared room               394

# %%
# no 2 : Jumlah review terbanyak
print("Jumlah reviwe terbanyak: ",df["number_of_reviews"].max())
# Out:
# Jumlah reviwe terbanyak:  323

# %%
# no 3 : 5 data dengan harga per malam termahal
df.sort_values(by="price", ascending=False).head(5).reset_index(drop=True)
# Out:
#          id                                             name    host_id  \
# 0  20791161  YOUR entire PRIVATE LUXURY PENTHOUSE condo unit  122991242
# 1  17831833               Comfortable & Quiet Master Bedroom   68223771
# 2  32026675                                          Testing   20307016
# 3  16395877         The Club Residences - Contemporary Manor   84411185
# 4  22617828     The Club Residences - Contemporary Manor (A)   84411185
#
#   host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 0        Jj         West Region              Tuas   1.31909  103.64656
# 1   Yolivia         West Region     Bukit Panjang   1.34775  103.77181
# 2     David      Central Region           Kallang   1.29610  103.86613
# 3    Darren      Central Region  Southern Islands   1.25284  103.82225
# 4    Darren      Central Region  Southern Islands   1.25054  103.82551
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# no 4 : Rumah dengan pemilik bernama Richard
df.loc[df["host_name"] == "Richard"].reset_index(drop=True)
# Out:
#          id                                            name   host_id  \
# 0    756267                             East Coast Boutique   1584407
# 1    819034                    Boutique 2 Bedroom Apartment   1584407
# 2    819044                             East Coast Hideaway   1584407
# 3   1622505                                   Terrace Suite   1584407
# 4   9337650  Modern Condo Apartment, Central Area with Pool  48443987
# 5  15274648                     Shophouse Chic with Terrace   1584407
# 6  18378142    New 2 Bd + 2 Bath Apt in CBD (Tanjong Pagar)   3927925
#
#   host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# 0   Richard      Central Region  Marine Parade   1.30377  103.89956
# 1   Richard      Central Region  Marine Parade   1.30529  103.90420
# 2   Richard      Central Region  Marine Parade   1.30392  103.89988
# 3   Richard      Central Region  Marine Parade   1.30415  103.90192
# ...

# %%
# no 5 : Koefisien korelasi antara harga rumah per malam dengan jumlah malam penyewaan minimum. Apakah
# berkorelasi lurus, terbalik, atau tidak berkolerasi? Jelaskan 
df["price"].corr(df["minimum_nights"])
# Out:
# -0.012213635484708467

# %%
# maka dari angka tersebut data tidak berkolerasi karena nilainnya hanya 0.01 yang dapat dilihat juga dari 
# grafik di bawah ini
import matplotlib.pyplot as plot
df.plot(kind="scatter", x="price", y="minimum_nights", xlabel="harga per malam",ylabel="jumlah malam minimum", label="Korelasi harga per malam dengan jumlah malam minimum")
plot.show()
