# %%
# NIM/Nama : 19622078 / Raden Francisco Trianto Bratadiningrat
# Tanggal : 23 November 2022
# Deskripsi : Problem 3, data pengguna kartu kredit suatu bank. Gambarkan

# import library 
import pandas as pd
import matplotlib.pyplot as plot
# loading data
df = pd.read_csv("P05-01.csv")
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# no 1 : Histogram distribusi total nominal yang belum dibayar pengguna dengan status aktif (Existing Customer), dengan bins 20.
(df.loc[df["Attrition_Flag"]=="Existing Customer"])["Total_Revolving_Bal"].plot(kind="hist", bins=20, label="Distribusi total nominal yang belum dibayar")
plot.show()

# %%
# no 2 : Pie chart perbandingan banyaknya masing-masing jenjang pendidikan terakhir dari pengguna dengan banyak transaksi selama 12 bulan terakhir di atas 30.
df.loc[df["Total_Trans_Amt"] > 30]["Education_Level"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Education_Level'>

# %%
# no 3 : Scatter plot dengan usia pengguna sebagai x dan nominal limit kartu kredit sebagai y dari pengguna berjenis kelamin laki-laki (M).
df.loc[df["Gender"]=="M"].plot(kind="scatter", x="Customer_Age", y="Credit_Limit")
plot.show()

# %%
# no 4 : Horizontal bar chart menggambarkan jumlah pengguna dari setiap tipe kartu.
df["Card_Category"].value_counts().plot(kind="barh")
plot.show()

# %%
# no 5 : Stacked bar chart dari pengguna dengan status perkawinan ’Married’, ’Single’, dan ’Divorced’ denganjenis kelamin sebagai sumbu x dan status perkawinan sebagai stacked y.
a = (df.loc[df["Marital_Status"] == "Married"].loc[df["Marital_Status"] != "Unknown"])["Marital_Status"].value_counts()
b = (df.loc[df["Gender"]=="M"].loc[df["Marital_Status"] != "Unknown"])["Marital_Status"].value_counts()
df1 = pd.DataFrame({"Married" : a, "Single" : b, "Divorced" : c}, index=["Male","Female"])
df1.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
a1 = (df.loc[df["Marital_Status"] == "Married"].loc[df["Gender"] == "M"])["Marital_Status"].value_counts()
a2 = (df.loc[df["Marital_Status"] == "Married"].loc[df["Gender"] == "F"])["Marital_Status"].value_counts()
b1 = (df.loc[df["Marital_Status"] == "Married"].loc[df["Gender"] == "M"])["Marital_Status"].value_counts()
b2 = (df.loc[df["Marital_Status"] == "Married"].loc[df["Gender"] == "F"])["Marital_Status"].value_counts()
c1 = (df.loc[df["Marital_Status"] == "Married"].loc[df["Gender"] == "M"])["Marital_Status"].value_counts()
c2 = (df.loc[df["Marital_Status"] == "Married"].loc[df["Gender"] == "F"])["Marital_Status"].value_counts()
